# %% [markdown]
# <a href="https://colab.research.google.com/github/ateeqshaik/myproject/blob/main/iris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

# %%
path="https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"

# %%
data=pd.read_csv(path, names=['sepal-length', 'sepal-width', 'petal-length', 'petal-width', 'Class'])

# %%
data
# Out:
#      sepal-length  sepal-width  petal-length  petal-width           Class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
data.shape
# Out:
# (150, 5)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
data['Class']=le.fit_transform(data['Class'])

# %%
data['Class']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: Class, Length: 150, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X=data.iloc[:,:-1].values
y=data.iloc[:,-1].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
from sklearn.tree import DecisionTreeClassifier
classifier=DecisionTreeClassifier()
classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=classifier.predict(X_test)

# %%
y_pred.size
y_pred
# Out:
# array([2, 1, 0, 2, 0, 2, 0, 1, 1, 1, 2, 1, 1, 1, 1, 0, 1, 1, 0, 0, 2, 1,
#        0, 0, 2, 0, 0, 1, 1, 0, 2, 1, 0, 2, 2, 1, 0, 2, 1, 1, 2, 0, 2, 0,
#        0])

# %%
accuracy=accuracy_score(y_test, y_pred)
print("Accuracy: ", accuracy)
# Out:
# Accuracy:  0.9777777777777777

# %%
cm=confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[16  0  0]
#  [ 0 17  1]
#  [ 0  0 11]]

# %%
sns.heatmap(cm, annot=True)
# Out:
# <Axes: >

# %%
result=classification_report(y_test, y_pred)
print(result)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        16
#            1       1.00      0.94      0.97        18
#            2       0.92      1.00      0.96        11
#
#     accuracy                           0.98        45
#    macro avg       0.97      0.98      0.98        45
# weighted avg       0.98      0.98      0.98        45

# %%
from sklearn.ensemble import RandomForestClassifier
classifier=RandomForestClassifier(n_estimators=20)
classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=20)

# %%
y_pred=classifier.predict(X_test)

# %%
accuracy=accuracy_score(y_test, y_pred)
print("Accuracy: ", accuracy)
# Out:
# Accuracy:  0.9777777777777777

# %%
cm=confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[16  0  0]
#  [ 0 17  1]
#  [ 0  0 11]]

# %%
sns.heatmap(cm,annot=True,fmt='g', xticklabels=['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], yticklabels=['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'])
# Out:
# <Axes: >

# %%
result=classification_report(y_test, y_pred)
print(result)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        16
#            1       1.00      0.94      0.97        18
#            2       0.92      1.00      0.96        11
#
#     accuracy                           0.98        45
#    macro avg       0.97      0.98      0.98        45
# weighted avg       0.98      0.98      0.98        45

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier=KNeighborsClassifier(n_neighbors=5)
classifier.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred=classifier.predict(X_test)

# %%
accuracy=accuracy_score(y_test, y_pred)
print("Accuracy: ", accuracy)
# Out:
# Accuracy:  0.9777777777777777

# %%
cm=confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[16  0  0]
#  [ 0 17  1]
#  [ 0  0 11]]

# %%
sns.heatmap(cm,annot=True,fmt='g', xticklabels=['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], yticklabels=['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'])
# Out:
# <Axes: >

# %%
# prompt: Apply neural network for this data

import tensorflow as tf
from tensorflow import keras

# Define the model
model = keras.Sequential([
    keras.layers.Dense(10, activation='relu', input_shape=(4,)), # Input layer with 4 features
    keras.layers.Dense(10, activation='relu'), # Hidden layer
    keras.layers.Dense(3, activation='softmax') # Output layer with 3 classes (softmax for probabilities)
])

# Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy', # Use sparse categorical crossentropy for integer labels
              metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=50) # Adjust epochs as needed

# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test)
print('Test accuracy:', accuracy)

# Make predictions
y_pred_prob = model.predict(X_test)
y_pred = np.argmax(y_pred_prob, axis=1)

# Confusion matrix and classification report
cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:\n", cm)
sns.heatmap(cm, annot=True, fmt='g', xticklabels=['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], yticklabels=['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'])
plt.show()
accuracy=accuracy_score(y_test, y_pred)
print("Accuracy: ", accuracy)
result = classification_report(y_test, y_pred)
print("Classification Report:\n", result)
# Out:
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.0059 - loss: 1.7175
# Epoch 2/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0038 - loss: 1.6719
# Epoch 3/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0059 - loss: 1.6495
# Epoch 4/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0149 - loss: 1.5075
# Epoch 5/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0302 - loss: 1.4935
# Epoch 6/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0302 - loss: 1.4575
# Epoch 7/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0340 - loss: 1.4379
# Epoch 8/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0590 - loss: 1.3907
# Epoch 9/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0704 - loss: 1.3699
# Epoch 10/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0517 - loss: 1.3270
# Epoch 11/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.1419 - loss: 1.2900
# Epoch 12/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.1557 - loss: 1.2462
# Epoch 13/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2113 - loss: 1.2038
# Epoch 14/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2196 - loss: 1.1913
# Epoch 15/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2883 - loss: 1.1384
# Epoch 16/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2792 - loss: 1.1392
# Epoch 17/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2851 - loss: 1.1029
# Epoch 18/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3278 - loss: 1.0745
# Epoch 19/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3552 - loss: 1.0415
# Epoch 20/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3795 - loss: 1.0187
# Epoch 21/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3621 - loss: 1.0113
# Epoch 22/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4499 - loss: 0.9929
# Epoch 23/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4634 - loss: 0.9909
# Epoch 24/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5182 - loss: 0.9588
# Epoch 25/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5515 - loss: 0.9577
# Epoch 26/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6143 - loss: 0.9092
# Epoch 27/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5865 - loss: 0.9100
# Epoch 28/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6365 - loss: 0.8664
# Epoch 29/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6528 - loss: 0.8531
# Epoch 30/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6212 - loss: 0.8480
# Epoch 31/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6250 - loss: 0.8309
# Epoch 32/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5969 - loss: 0.8272
# Epoch 33/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6143 - loss: 0.8171
# Epoch 34/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6396 - loss: 0.8040
# Epoch 35/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6552 - loss: 0.7894
# Epoch 36/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7146 - loss: 0.7392
# Epoch 37/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6809 - loss: 0.7495
# Epoch 38/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6902 - loss: 0.7210
# Epoch 39/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6885 - loss: 0.7378
# Epoch 40/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7211 - loss: 0.6924
# Epoch 41/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7478 - loss: 0.6730
# Epoch 42/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7739 - loss: 0.6365
# Epoch 43/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7725 - loss: 0.6531
# Epoch 44/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7732 - loss: 0.6567
# Epoch 45/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7617 - loss: 0.6604
# Epoch 46/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7957 - loss: 0.6237
# Epoch 47/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7561 - loss: 0.6640
# Epoch 48/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7957 - loss: 0.6202
# Epoch 49/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7891 - loss: 0.6125
# Epoch 50/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7943 - loss: 0.5814
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6528 - loss: 0.6855
# Test accuracy: 0.6666666865348816
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Confusion Matrix:
#  [[16  0  0]
#  [ 0  3 15]
#  [ 0  0 11]]
# Accuracy:  0.6666666666666666
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        16
#            1       1.00      0.17      0.29        18
#            2       0.42      1.00      0.59        11
#
#     accuracy                           0.67        45
#    macro avg       0.81      0.72      0.63        45
# weighted avg       0.86      0.67      0.62        45
